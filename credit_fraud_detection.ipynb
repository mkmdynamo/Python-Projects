# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.model_selection  import cross_val_score
from imblearn.over_sampling import SMOTE
from sklearn.metrics import precision_score, recall_score, f1_score, mean_squared_error
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

from sklearn.cluster import KMeans

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout

import warnings
warnings.filterwarnings("ignore")
# Out:
# 2024-05-26 18:35:21.308944: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-26 18:35:21.309119: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-26 18:35:21.492179: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# # Preprocessing

# %%
data= pd.read_csv('/kaggle/input/creditcardfraud/creditcard.csv')
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
print('No Frauds', round(data['Class'].value_counts()[0]/len(data) * 100,2), '% of the dataset')
print('Frauds', round(data['Class'].value_counts()[1]/len(data) * 100,2), '% of the dataset')
# Out:
# No Frauds 99.83 % of the dataset
# Frauds 0.17 % of the dataset

# %%
sns.countplot(x='Class',data = data)
plt.title('Class Distributions \n (0: No Fraud || 1: Fraud)', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Class Distributions \n (0: No Fraud || 1: Fraud)')

# %%
tmp = df[['Amount','Class']].copy()
class_0 = tmp.loc[tmp['Class'] == 0]['Amount']
class_1 = tmp.loc[tmp['Class'] == 1]['Amount']

# %%
class_0.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
class_1.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# The real transaction have a larger mean value, larger Q1, smaller Q3 and Q4 and larger outliers; fraudulent transactions have a smaller Q1 and mean, larger Q4 and smaller outliers.

# %%
dataplot = sns.heatmap(data.corr(), cmap="Blues") 
plt.show()

# %%
X = data.drop("Class", axis=1)
y = data['Class']

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
X
# Out:
# array([[0.00000000e+00, 9.35192337e-01, 7.66490419e-01, ...,
#         4.18976135e-01, 3.12696634e-01, 5.82379309e-03],
#        [0.00000000e+00, 9.78541955e-01, 7.70066651e-01, ...,
#         4.16345145e-01, 3.13422663e-01, 1.04705276e-04],
#        [5.78730497e-06, 9.35217023e-01, 7.53117667e-01, ...,
#         4.15489266e-01, 3.11911316e-01, 1.47389219e-02],
#        ...,
#        [9.99976851e-01, 9.90904812e-01, 7.64079694e-01, ...,
#         4.16593177e-01, 3.12584864e-01, 2.64215395e-03],
#        [9.99976851e-01, 9.54208999e-01, 7.72855742e-01, ...,
#         4.18519535e-01, 3.15245157e-01, 3.89238944e-04],
#        [1.00000000e+00, 9.49231759e-01, 7.65256401e-01, ...,
#         4.16466371e-01, 3.13400843e-01, 8.44648509e-03]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42,test_size=0.2,stratify=y)

# %%
y_train.value_counts()
# Out:
# Class
# 0    227451
# 1       394
# Name: count, dtype: int64

# %%
smote = SMOTE(random_state=0)

X_train, y_train = smote.fit_resample(X_train,y_train)
X_test, y_test = smote.fit_resample(X_test,y_test)

# %%
y_train.value_counts()
# Out:
# Class
# 0    227451
# 1    227451
# Name: count, dtype: int64

# %% [markdown]
# # Model

# %%
def evaluate(model):
  model.fit(X_train,y_train)
  pre = model.predict(X_test)
    
  accuracy = accuracy_score(pre,y_test)
  recall = recall_score(pre,y_test)
  f1 = f1_score(pre,y_test)

  sns.heatmap(confusion_matrix(pre,y_test),annot=True)
  print(model)
  print('Accuracy : ',accuracy,'Recall : ',recall,"F1 : ",f1)

# %%
model_LR = LogisticRegression()

# %%
#perform cross validation

grid={"C":np.logspace(-3,3,7), "penalty":["l2"]}  # l2 ridge

clf_lsr_cv = GridSearchCV(model_LR,grid,cv=3,scoring='roc_auc')
clf_lsr_cv.fit(X_train,y_train)

print("tuned hpyerparameters :(best parameters) ",clf_lsr_cv.best_params_)
print("accuracy :",clf_lsr_cv.best_score_)
# Out:
# tuned hpyerparameters :(best parameters)  {'C': 1000.0, 'penalty': 'l2'}
# accuracy : 0.9912871004337417

# %%
# Fitting the model with best parameters .

lsr_best = LogisticRegression(penalty='l2',C=1000.0,random_state = 42)
lsr_clf = lsr_best.fit(X_train,y_train)
evaluate(lsr_clf)
# Out:
# LogisticRegression(C=1000.0, random_state=42)
# Accuracy :  0.944868458075408 Recall :  0.9716597680575754 F1 :  0.9432568915274484

# %%
model_KNN = KNeighborsClassifier()

# %%
k_range = np.arange(1, 20, 2)
scores = [] #to store cross val score for each k
for k in k_range:
  model_KNN  = KNeighborsClassifier(n_neighbors=k)
  model_KNN .fit(X_train,y_train)
  score = cross_val_score(model_KNN , X_train, y_train, cv=3, n_jobs = -1)
  scores.append(score.mean())

#Storing the mean squared error to decide optimum k
mse = [1-x for x in scores]

# %%
plt.figure(figsize=(20,8))
plt.subplot(121)
sns.lineplot(x=k_range,y=mse,markers=True,dashes=False)
plt.xlabel("Value of K")
plt.ylabel("Mean Squared Error")
plt.subplot(122)
sns.lineplot(x=k_range,y=scores,markers=True,dashes=False)
plt.xlabel("Value of K")
plt.ylabel("Cross Validation Accuracy")

plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors=3)

knn_clf = knn.fit(X_train,y_train)

evaluate(knn_clf)
# Out:
# KNeighborsClassifier(n_neighbors=3)
# Accuracy :  0.927335396736072 Recall :  0.998911838377202 F1 :  0.9217201856588045

# %%
model_RFC = RandomForestClassifier()

# %%
# Using grid search cv to find the best parameters.

param = {'n_estimators': [10, 20, 30, 40, 50], 'max_depth': [2, 3, 4, 7, 9]}
clf_rfc_cv = GridSearchCV(model_RFC, param, cv=5,scoring='roc_auc', n_jobs=-1)
clf_rfc_cv.fit(X_train,y_train)

print("tuned hpyerparameters :(best parameters) ",clf_rfc_cv.best_params_)
print("accuracy :",clf_rfc_cv.best_score_)
# Out:
# tuned hpyerparameters :(best parameters)  {'max_depth': 9, 'n_estimators': 50}
# accuracy : 0.9992863864705697

# %%
#Fitting model 

rf = RandomForestClassifier(max_depth=9, n_estimators=50)
RFC_clf = rf.fit(X_train,y_train)

evaluate(RFC_clf)
# Out:
# RandomForestClassifier(max_depth=9, n_estimators=50)
# Accuracy :  0.9401466657287564 Recall :  0.9965085599793687 F1 :  0.9365450765803137

# %%
model_ANN = Sequential([
    Dense(32, activation='relu', input_dim=X_train.shape[1]),

    Dense(16, activation='relu'),
  
    Dense(8, activation='relu'),
.3
    Dense(1, activation='sigmoid')
])

model_ANN.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_ANN.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │           992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,665 (6.50 KB)
#  Trainable params: 1,665 (6.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model_ANN.fit(X_train, y_train, epochs=50, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - accuracy: 0.9185 - loss: 0.2034 - val_accuracy: 0.8938 - val_loss: 0.1964
# Epoch 2/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - accuracy: 0.9524 - loss: 0.1206 - val_accuracy: 0.9431 - val_loss: 0.1186
# Epoch 3/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9582 - loss: 0.1051 - val_accuracy: 0.9551 - val_loss: 0.0927
# Epoch 4/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9613 - loss: 0.0966 - val_accuracy: 0.9303 - val_loss: 0.1474
# Epoch 5/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9634 - loss: 0.0909 - val_accuracy: 0.9609 - val_loss: 0.0887
# Epoch 6/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.9658 - loss: 0.0847 - val_accuracy: 0.9571 - val_loss: 0.0923
# Epoch 7/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9675 - loss: 0.0801 - val_accuracy: 0.9831 - val_loss: 0.0522
# Epoch 8/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - accuracy: 0.9692 - loss: 0.0746 - val_accuracy: 0.9139 - val_loss: 0.2240
# Epoch 9/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - accuracy: 0.9712 - loss: 0.0704 - val_accuracy: 0.9666 - val_loss: 0.0757
# Epoch 10/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9726 - loss: 0.0656 - val_accuracy: 0.9219 - val_loss: 0.1757
# Epoch 11/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - accuracy: 0.9737 - loss: 0.0635 - val_accuracy: 0.9775 - val_loss: 0.0611
# Epoch 12/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9750 - loss: 0.0607 - val_accuracy: 0.9859 - val_loss: 0.0406
# Epoch 13/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - accuracy: 0.9759 - loss: 0.0580 - val_accuracy: 0.9476 - val_loss: 0.1235
# Epoch 14/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - accuracy: 0.9773 - loss: 0.0558 - val_accuracy: 0.9855 - val_loss: 0.0414
# Epoch 15/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - accuracy: 0.9781 - loss: 0.0536 - val_accuracy: 0.9883 - val_loss: 0.0320
# Epoch 16/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9796 - loss: 0.0504 - val_accuracy: 0.9609 - val_loss: 0.0808
# Epoch 17/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - accuracy: 0.9808 - loss: 0.0477 - val_accuracy: 0.9811 - val_loss: 0.0514
# Epoch 18/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - accuracy: 0.9814 - loss: 0.0458 - val_accuracy: 0.9713 - val_loss: 0.0729
# Epoch 19/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9822 - loss: 0.0448 - val_accuracy: 0.9698 - val_loss: 0.0665
# Epoch 20/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9837 - loss: 0.0422 - val_accuracy: 0.9655 - val_loss: 0.0845
# Epoch 21/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9844 - loss: 0.0395 - val_accuracy: 0.9882 - val_loss: 0.0401
# Epoch 22/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9845 - loss: 0.0396 - val_accuracy: 0.9800 - val_loss: 0.0504
# Epoch 23/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9851 - loss: 0.0380 - val_accuracy: 0.9824 - val_loss: 0.0452
# Epoch 24/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - accuracy: 0.9857 - loss: 0.0360 - val_accuracy: 0.9925 - val_loss: 0.0216
# Epoch 25/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - accuracy: 0.9864 - loss: 0.0354 - val_accuracy: 0.9924 - val_loss: 0.0250
# Epoch 26/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - accuracy: 0.9872 - loss: 0.0325 - val_accuracy: 0.9949 - val_loss: 0.0261
# Epoch 27/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.9874 - loss: 0.0330 - val_accuracy: 0.9801 - val_loss: 0.0494
# Epoch 28/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - accuracy: 0.9884 - loss: 0.0310 - val_accuracy: 0.9764 - val_loss: 0.0605
# Epoch 29/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9887 - loss: 0.0302 - val_accuracy: 0.9860 - val_loss: 0.0375
# Epoch 30/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9890 - loss: 0.0291 - val_accuracy: 0.9676 - val_loss: 0.0669
# Epoch 31/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9892 - loss: 0.0287 - val_accuracy: 0.9908 - val_loss: 0.0269
# Epoch 32/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9897 - loss: 0.0272 - val_accuracy: 0.9692 - val_loss: 0.0941
# Epoch 33/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9893 - loss: 0.0283 - val_accuracy: 0.9982 - val_loss: 0.0118
# Epoch 34/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - accuracy: 0.9905 - loss: 0.0265 - val_accuracy: 0.9839 - val_loss: 0.0387
# Epoch 35/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9902 - loss: 0.0265 - val_accuracy: 0.9911 - val_loss: 0.0241
# Epoch 36/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9905 - loss: 0.0256 - val_accuracy: 0.9881 - val_loss: 0.0297
# Epoch 37/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9906 - loss: 0.0257 - val_accuracy: 0.9988 - val_loss: 0.0099
# Epoch 38/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9906 - loss: 0.0255 - val_accuracy: 0.9936 - val_loss: 0.0189
# Epoch 39/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9916 - loss: 0.0231 - val_accuracy: 0.9983 - val_loss: 0.0132
# Epoch 40/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - accuracy: 0.9909 - loss: 0.0248 - val_accuracy: 0.9960 - val_loss: 0.0192
# Epoch 41/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - accuracy: 0.9922 - loss: 0.0225 - val_accuracy: 0.9719 - val_loss: 0.0701
# Epoch 42/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9906 - loss: 0.0271 - val_accuracy: 0.9972 - val_loss: 0.0129
# Epoch 43/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9919 - loss: 0.0226 - val_accuracy: 0.9985 - val_loss: 0.0104
# Epoch 44/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9917 - loss: 0.0226 - val_accuracy: 0.9998 - val_loss: 0.0062
# Epoch 45/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.9918 - loss: 0.0225 - val_accuracy: 0.9987 - val_loss: 0.0081
# Epoch 46/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - accuracy: 0.9919 - loss: 0.0227 - val_accuracy: 0.9983 - val_loss: 0.0102
# Epoch 47/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9926 - loss: 0.0207 - val_accuracy: 0.9978 - val_loss: 0.0118
# Epoch 48/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - accuracy: 0.9933 - loss: 0.0193 - val_accuracy: 0.9996 - val_loss: 0.0050
# Epoch 49/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9926 - loss: 0.0209 - val_accuracy: 0.9986 - val_loss: 0.0076
# Epoch 50/50
# 5687/5687 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9927 - loss: 0.0211 - val_accuracy: 0.9982 - val_loss: 0.0085

# %%
y_pred = model_ANN.predict(X_test)
y_pred = (y_pred > 0.5)
# Out:
# 3554/3554 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step

# %%
classification_report(y_pred,y_test)
# Out:
# '              precision    recall  f1-score   support\n\n       False       0.99      0.88      0.93     63944\n        True       0.87      0.99      0.93     49784\n\n    accuracy                           0.93    113728\n   macro avg       0.93      0.94      0.93    113728\nweighted avg       0.94      0.93      0.93    113728\n'

# %%
cm = confusion_matrix(y_test,y_pred)
sns.heatmap(cm, annot=True)
plt.show()

# %%
kmeans = KMeans(n_clusters = 2, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 42)
y_kmeans = kmeans.fit_predict(X)

# %%
X
# Out:
# array([[0.00000000e+00, 9.35192337e-01, 7.66490419e-01, ...,
#         4.18976135e-01, 3.12696634e-01, 5.82379309e-03],
#        [0.00000000e+00, 9.78541955e-01, 7.70066651e-01, ...,
#         4.16345145e-01, 3.13422663e-01, 1.04705276e-04],
#        [5.78730497e-06, 9.35217023e-01, 7.53117667e-01, ...,
#         4.15489266e-01, 3.11911316e-01, 1.47389219e-02],
#        ...,
#        [9.99976851e-01, 9.90904812e-01, 7.64079694e-01, ...,
#         4.16593177e-01, 3.12584864e-01, 2.64215395e-03],
#        [9.99976851e-01, 9.54208999e-01, 7.72855742e-01, ...,
#         4.18519535e-01, 3.15245157e-01, 3.89238944e-04],
#        [1.00000000e+00, 9.49231759e-01, 7.65256401e-01, ...,
#         4.16466371e-01, 3.13400843e-01, 8.44648509e-03]])

# %%
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], 
            s = 100, c = 'red', label = 'non-Fraud')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], 
            s = 100, c = 'blue', label = 'Fraud')

# Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], 
            s = 100, c = 'yellow', label = 'Centroids')

plt.legend()
